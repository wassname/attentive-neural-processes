# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import collections
from pathlib import Path
from tqdm.auto import tqdm

import math
# %pylab inline
# %reload_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/wassname/.pyenv/versions/3.7.2/envs/jup3.7.2/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import logging
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logger = logging.getLogger("smartmeters.ipynb")

# %%
import torch
from torch import nn
import torch.nn.functional as F

# %%
from src.models.model import LatentModel
from src.data.smart_meter import collate_fns, SmartMeterDataSet, get_smartmeter_df
from src.plot import plot_from_loader

# %%
# Params
device='cuda'
batch_size=32
num_workers=3
use_logy=False
num_context, num_extra_target = 24*2*6, 24*2
esp=1e-4

# %% [markdown]
# # Load kaggle smart meter data

# %%
df_train, df_test = get_smartmeter_df()

# %%
df_train['energy(kWh/hh)'].plot(label='train')
df_test['energy(kWh/hh)'].plot(label='test')
plt.title('energy(kWh/hh)')
plt.legend()

# %% [markdown]
# # Dataloaders

# %%
data_train = SmartMeterDataSet(df_train, num_context, num_extra_target)
data_test = SmartMeterDataSet(df_test, num_context, num_extra_target)

# %%
loader_train = torch.utils.data.DataLoader(data_train, batch_size=batch_size, shuffle=True, 
    collate_fn=collate_fns(num_context, num_extra_target, sample=True),
    num_workers=num_workers,
)

loader_test = torch.utils.data.DataLoader(data_test, batch_size=batch_size, shuffle=False, 
    collate_fn=collate_fns(num_context, num_extra_target, sample=False)
)

# %% [markdown]
# # Run

# %%
x, y, _, _ = next(iter(loader_train))
x.shape, y.shape
# Out:
# (torch.Size([32, 176, 17]), torch.Size([32, 176, 1]))

# %%
# # [I 2020-02-01 23:14:15,952] Finished trial#58 resulted in value: -1.3353958129882812. Current 
# # best value is -1.586141586303711 with parameters: 
# a = {
#     'attention_dropout': 0.2,
#     'attention_layers': 2,
#     'batch_size': 16,
#     'batchnorm': False,
#     'det_enc_cross_attn_type': 'multihead',
#     'det_enc_self_attn_type': 'ptmultihead',
#     'dropout': 0,
#     'grad_clip': 40,
#     'hidden_dim': 64,
#     'latent_dim': 64,
#     'latent_enc_self_attn_type': 'multihead',
#     'learning_rate': 0.001922598180719319,
#     'max_nb_epochs': 2,
#     'min_std': 0.005,
#     'n_decoder_layers': 2,
#     'n_det_encoder_layers': 8,
#     'n_latent_encoder_layers': 1,
#     'num_context': 48,
#     'num_extra_target': 24,
#     'num_heads': 8,
#     'num_workers': 4,
#     'use_deterministic_path': False,
#     'use_lvar': True,
#     'use_self_attn': True,
#     'vis_i': 670,
#     'x_dim': 16,
#     'y_dim': 1
# }

# %%
from src.models.model import LatentModel
model = LatentModel(
    x_dim=x.shape[-1], 
    y_dim=y.shape[-1], 
    hidden_dim=64*3,
    latent_dim=64*3,
#     dropout=0.,
    min_std=0.01,
#     attention_dropout=0.2,
    num_heads=8,
    n_latent_encoder_layers=2,
    n_det_encoder_layers=4,
    n_decoder_layers=3,
    attention_layers=2,
    latent_enc_self_attn_type="multihead", 
    det_enc_self_attn_type="multihead",
    det_enc_cross_attn_type="multihead",
    use_self_attn=True,
    batchnorm=False,
    use_lvar=False,
    use_deterministic_path=False
).to(device)

optim = torch.optim.AdamW(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optim, patience=4)

# %%
from torchsummaryX import summary
data = next(iter(loader_train))
data = [d.to(device) for d in data]
context_x, context_y, target_x, target_y = data
with torch.no_grad():
    model.eval()
    summary(model, context_x, context_y, target_x, target_y)
    dist, log_p, kl, loss_mse, loss = model(context_x, context_y, target_x, target_y)
# Out:
# =======================================================================================================
#                                                    Kernel Shape  \
# Layer
# 0__latent_encoder.Linear__input_layer                 [18, 192]
# 1__latent_encoder._encoder.0.Linear_linear           [192, 192]
# 2__latent_encoder._encoder.0.ReLU_act                         -
# 3__latent_encoder._encoder.0.Dropout2d_dropout                -
# 4__latent_encoder._encoder.1.Linear_linear           [192, 192]
# 5__latent_encoder._encoder.1.ReLU_act                         -
# 6__latent_encoder._encoder.1.Dropout2d_dropout                -
# 7__latent_encoder._self_attention._W_k.0.Linear...   [192, 192]
# 8__latent_encoder._self_attention._W_v.0.Linear...   [192, 192]
# 9__latent_encoder._self_attention._W_q.0.Linear...   [192, 192]
# 10__latent_encoder._self_attention._W_k.1.Linea...   [192, 192]
# 11__latent_encoder._self_attention._W_v.1.Linea...   [192, 192]
# 12__latent_encoder._self_attention._W_q.1.Linea...   [192, 192]
# 13__latent_encoder._self_attention._W_k.2.Linea...   [192, 192]
# 14__latent_encoder._self_attention._W_v.2.Linea...   [192, 192]
# 15__latent_encoder._self_attention._W_q.2.Linea...   [192, 192]
# 16__latent_encoder._self_attention._W_k.3.Linea...   [192, 192]
# 17__latent_encoder._self_attention._W_v.3.Linea...   [192, 192]
# 18__latent_encoder._self_attention._W_q.3.Linea...   [192, 192]
# 19__latent_encoder._self_attention._W_k.4.Linea...   [192, 192]
# 20__latent_encoder._self_attention._W_v.4.Linea...   [192, 192]
# 21__latent_encoder._self_attention._W_q.4.Linea...   [192, 192]
# 22__latent_encoder._self_attention._W_k.5.Linea...   [192, 192]
# 23__latent_encoder._self_attention._W_v.5.Linea...   [192, 192]
# 24__latent_encoder._self_attention._W_q.5.Linea...   [192, 192]
# 25__latent_encoder._self_attention._W_k.6.Linea...   [192, 192]
# 26__latent_encoder._self_attention._W_v.6.Linea...   [192, 192]
# 27__latent_encoder._self_attention._W_q.6.Linea...   [192, 192]
# 28__latent_encoder._self_attention._W_k.7.Linea...   [192, 192]
# 29__latent_encoder._self_attention._W_v.7.Linea...   [192, 192]
# 30__latent_encoder._self_attention._W_q.7.Linea...   [192, 192]
# 31__latent_encoder._self_attention._W.Linear_li...  [1536, 192]
# 32__latent_encoder.Linear__penultimate_layer         [192, 192]
# 33__latent_encoder.Linear__mean                      [192, 192]
# 34__latent_encoder.Linear__log_var                   [192, 192]
# 35__latent_encoder.Linear__input_layer                [18, 192]
# 36__latent_encoder._encoder.0.Linear_linear          [192, 192]
# 37__latent_encoder._encoder.0.ReLU_act                        -
# 38__latent_encoder._encoder.0.Dropout2d_dropout               -
# 39__latent_encoder._encoder.1.Linear_linear          [192, 192]
# 40__latent_encoder._encoder.1.ReLU_act                        -
# 41__latent_encoder._encoder.1.Dropout2d_dropout               -
# 42__latent_encoder._self_attention._W_k.0.Linea...   [192, 192]
# 43__latent_encoder._self_attention._W_v.0.Linea...   [192, 192]
# 44__latent_encoder._self_attention._W_q.0.Linea...   [192, 192]
# 45__latent_encoder._self_attention._W_k.1.Linea...   [192, 192]
# 46__latent_encoder._self_attention._W_v.1.Linea...   [192, 192]
# 47__latent_encoder._self_attention._W_q.1.Linea...   [192, 192]
# 48__latent_encoder._self_attention._W_k.2.Linea...   [192, 192]
# 49__latent_encoder._self_attention._W_v.2.Linea...   [192, 192]
# 50__latent_encoder._self_attention._W_q.2.Linea...   [192, 192]
# 51__latent_encoder._self_attention._W_k.3.Linea...   [192, 192]
# 52__latent_encoder._self_attention._W_v.3.Linea...   [192, 192]
# 53__latent_encoder._self_attention._W_q.3.Linea...   [192, 192]
# 54__latent_encoder._self_attention._W_k.4.Linea...   [192, 192]
# 55__latent_encoder._self_attention._W_v.4.Linea...   [192, 192]
# 56__latent_encoder._self_attention._W_q.4.Linea...   [192, 192]
# 57__latent_encoder._self_attention._W_k.5.Linea...   [192, 192]
# 58__latent_encoder._self_attention._W_v.5.Linea...   [192, 192]
# 59__latent_encoder._self_attention._W_q.5.Linea...   [192, 192]
# 60__latent_encoder._self_attention._W_k.6.Linea...   [192, 192]
# 61__latent_encoder._self_attention._W_v.6.Linea...   [192, 192]
# 62__latent_encoder._self_attention._W_q.6.Linea...   [192, 192]
# 63__latent_encoder._self_attention._W_k.7.Linea...   [192, 192]
# 64__latent_encoder._self_attention._W_v.7.Linea...   [192, 192]
# 65__latent_encoder._self_attention._W_q.7.Linea...   [192, 192]
# 66__latent_encoder._self_attention._W.Linear_li...  [1536, 192]
# 67__latent_encoder.Linear__penultimate_layer         [192, 192]
# 68__latent_encoder.Linear__mean                      [192, 192]
# 69__latent_encoder.Linear__log_var                   [192, 192]
# 70__decoder.Linear__target_transform                  [17, 192]
# 71__decoder._decoder.0.Linear_linear                 [384, 384]
# 72__decoder._decoder.0.ReLU_act                               -
# 73__decoder._decoder.0.Dropout2d_dropout                      -
# 74__decoder._decoder.1.Linear_linear                 [384, 384]
# 75__decoder._decoder.1.ReLU_act                               -
# 76__decoder._decoder.1.Dropout2d_dropout                      -
# 77__decoder._decoder.2.Linear_linear                 [384, 384]
# 78__decoder._decoder.2.ReLU_act                               -
# 79__decoder._decoder.2.Dropout2d_dropout                      -
# 80__decoder.Linear__mean                               [384, 1]
# 81__decoder.Linear__std                                [384, 1]
#
#                                                          Output Shape  \
# Layer
# 0__latent_encoder.Linear__input_layer                  [32, 170, 192]
# 1__latent_encoder._encoder.0.Linear_linear             [32, 170, 192]
# 2__latent_encoder._encoder.0.ReLU_act                  [32, 170, 192]
# 3__latent_encoder._encoder.0.Dropout2d_dropout      [32, 192, 170, 1]
# 4__latent_encoder._encoder.1.Linear_linear             [32, 170, 192]
# 5__latent_encoder._encoder.1.ReLU_act                  [32, 170, 192]
# 6__latent_encoder._encoder.1.Dropout2d_dropout      [32, 192, 170, 1]
# 7__latent_encoder._self_attention._W_k.0.Linear...     [32, 170, 192]
# 8__latent_encoder._self_attention._W_v.0.Linear...     [32, 170, 192]
# 9__latent_encoder._self_attention._W_q.0.Linear...     [32, 170, 192]
# 10__latent_encoder._self_attention._W_k.1.Linea...     [32, 170, 192]
# 11__latent_encoder._self_attention._W_v.1.Linea...     [32, 170, 192]
# 12__latent_encoder._self_attention._W_q.1.Linea...     [32, 170, 192]
# 13__latent_encoder._self_attention._W_k.2.Linea...     [32, 170, 192]
# 14__latent_encoder._self_attention._W_v.2.Linea...     [32, 170, 192]
# 15__latent_encoder._self_attention._W_q.2.Linea...     [32, 170, 192]
# 16__latent_encoder._self_attention._W_k.3.Linea...     [32, 170, 192]
# 17__latent_encoder._self_attention._W_v.3.Linea...     [32, 170, 192]
# 18__latent_encoder._self_attention._W_q.3.Linea...     [32, 170, 192]
# 19__latent_encoder._self_attention._W_k.4.Linea...     [32, 170, 192]
# 20__latent_encoder._self_attention._W_v.4.Linea...     [32, 170, 192]
# 21__latent_encoder._self_attention._W_q.4.Linea...     [32, 170, 192]
# 22__latent_encoder._self_attention._W_k.5.Linea...     [32, 170, 192]
# 23__latent_encoder._self_attention._W_v.5.Linea...     [32, 170, 192]
# 24__latent_encoder._self_attention._W_q.5.Linea...     [32, 170, 192]
# 25__latent_encoder._self_attention._W_k.6.Linea...     [32, 170, 192]
# 26__latent_encoder._self_attention._W_v.6.Linea...     [32, 170, 192]
# 27__latent_encoder._self_attention._W_q.6.Linea...     [32, 170, 192]
# 28__latent_encoder._self_attention._W_k.7.Linea...     [32, 170, 192]
# 29__latent_encoder._self_attention._W_v.7.Linea...     [32, 170, 192]
# 30__latent_encoder._self_attention._W_q.7.Linea...     [32, 170, 192]
# 31__latent_encoder._self_attention._W.Linear_li...     [32, 170, 192]
# 32__latent_encoder.Linear__penultimate_layer                [32, 192]
# 33__latent_encoder.Linear__mean                             [32, 192]
# 34__latent_encoder.Linear__log_var                          [32, 192]
# 35__latent_encoder.Linear__input_layer                 [32, 198, 192]
# 36__latent_encoder._encoder.0.Linear_linear            [32, 198, 192]
# 37__latent_encoder._encoder.0.ReLU_act                 [32, 198, 192]
# 38__latent_encoder._encoder.0.Dropout2d_dropout     [32, 192, 198, 1]
# 39__latent_encoder._encoder.1.Linear_linear            [32, 198, 192]
# 40__latent_encoder._encoder.1.ReLU_act                 [32, 198, 192]
# 41__latent_encoder._encoder.1.Dropout2d_dropout     [32, 192, 198, 1]
# 42__latent_encoder._self_attention._W_k.0.Linea...     [32, 198, 192]
# 43__latent_encoder._self_attention._W_v.0.Linea...     [32, 198, 192]
# 44__latent_encoder._self_attention._W_q.0.Linea...     [32, 198, 192]
# 45__latent_encoder._self_attention._W_k.1.Linea...     [32, 198, 192]
# 46__latent_encoder._self_attention._W_v.1.Linea...     [32, 198, 192]
# 47__latent_encoder._self_attention._W_q.1.Linea...     [32, 198, 192]
# 48__latent_encoder._self_attention._W_k.2.Linea...     [32, 198, 192]
# 49__latent_encoder._self_attention._W_v.2.Linea...     [32, 198, 192]
# 50__latent_encoder._self_attention._W_q.2.Linea...     [32, 198, 192]
# 51__latent_encoder._self_attention._W_k.3.Linea...     [32, 198, 192]
# 52__latent_encoder._self_attention._W_v.3.Linea...     [32, 198, 192]
# 53__latent_encoder._self_attention._W_q.3.Linea...     [32, 198, 192]
# 54__latent_encoder._self_attention._W_k.4.Linea...     [32, 198, 192]
# 55__latent_encoder._self_attention._W_v.4.Linea...     [32, 198, 192]
# 56__latent_encoder._self_attention._W_q.4.Linea...     [32, 198, 192]
# 57__latent_encoder._self_attention._W_k.5.Linea...     [32, 198, 192]
# 58__latent_encoder._self_attention._W_v.5.Linea...     [32, 198, 192]
# 59__latent_encoder._self_attention._W_q.5.Linea...     [32, 198, 192]
# 60__latent_encoder._self_attention._W_k.6.Linea...     [32, 198, 192]
# 61__latent_encoder._self_attention._W_v.6.Linea...     [32, 198, 192]
# 62__latent_encoder._self_attention._W_q.6.Linea...     [32, 198, 192]
# 63__latent_encoder._self_attention._W_k.7.Linea...     [32, 198, 192]
# 64__latent_encoder._self_attention._W_v.7.Linea...     [32, 198, 192]
# 65__latent_encoder._self_attention._W_q.7.Linea...     [32, 198, 192]
# 66__latent_encoder._self_attention._W.Linear_li...     [32, 198, 192]
# 67__latent_encoder.Linear__penultimate_layer                [32, 192]
# 68__latent_encoder.Linear__mean                             [32, 192]
# 69__latent_encoder.Linear__log_var                          [32, 192]
# 70__decoder.Linear__target_transform                   [32, 198, 192]
# 71__decoder._decoder.0.Linear_linear                   [32, 198, 384]
# 72__decoder._decoder.0.ReLU_act                        [32, 198, 384]
# 73__decoder._decoder.0.Dropout2d_dropout            [32, 384, 198, 1]
# 74__decoder._decoder.1.Linear_linear                   [32, 198, 384]
# 75__decoder._decoder.1.ReLU_act                        [32, 198, 384]
# 76__decoder._decoder.1.Dropout2d_dropout            [32, 384, 198, 1]
# 77__decoder._decoder.2.Linear_linear                   [32, 198, 384]
# 78__decoder._decoder.2.ReLU_act                        [32, 198, 384]
# 79__decoder._decoder.2.Dropout2d_dropout            [32, 384, 198, 1]
# 80__decoder.Linear__mean                                 [32, 198, 1]
# 81__decoder.Linear__std                                  [32, 198, 1]
#
#                                                       Params Mult-Adds
# Layer
# 0__latent_encoder.Linear__input_layer                 3.648k    3.456k
# 1__latent_encoder._encoder.0.Linear_linear           36.864k   36.864k
# 2__latent_encoder._encoder.0.ReLU_act                      -         -
# 3__latent_encoder._encoder.0.Dropout2d_dropout             -         -
# 4__latent_encoder._encoder.1.Linear_linear           36.864k   36.864k
# 5__latent_encoder._encoder.1.ReLU_act                      -         -
# 6__latent_encoder._encoder.1.Dropout2d_dropout             -         -
# 7__latent_encoder._self_attention._W_k.0.Linear...   36.864k   36.864k
# 8__latent_encoder._self_attention._W_v.0.Linear...   36.864k   36.864k
# 9__latent_encoder._self_attention._W_q.0.Linear...   36.864k   36.864k
# 10__latent_encoder._self_attention._W_k.1.Linea...   36.864k   36.864k
# 11__latent_encoder._self_attention._W_v.1.Linea...   36.864k   36.864k
# 12__latent_encoder._self_attention._W_q.1.Linea...   36.864k   36.864k
# 13__latent_encoder._self_attention._W_k.2.Linea...   36.864k   36.864k
# 14__latent_encoder._self_attention._W_v.2.Linea...   36.864k   36.864k
# 15__latent_encoder._self_attention._W_q.2.Linea...   36.864k   36.864k
# 16__latent_encoder._self_attention._W_k.3.Linea...   36.864k   36.864k
# 17__latent_encoder._self_attention._W_v.3.Linea...   36.864k   36.864k
# 18__latent_encoder._self_attention._W_q.3.Linea...   36.864k   36.864k
# 19__latent_encoder._self_attention._W_k.4.Linea...   36.864k   36.864k
# 20__latent_encoder._self_attention._W_v.4.Linea...   36.864k   36.864k
# 21__latent_encoder._self_attention._W_q.4.Linea...   36.864k   36.864k
# 22__latent_encoder._self_attention._W_k.5.Linea...   36.864k   36.864k
# 23__latent_encoder._self_attention._W_v.5.Linea...   36.864k   36.864k
# 24__latent_encoder._self_attention._W_q.5.Linea...   36.864k   36.864k
# 25__latent_encoder._self_attention._W_k.6.Linea...   36.864k   36.864k
# 26__latent_encoder._self_attention._W_v.6.Linea...   36.864k   36.864k
# 27__latent_encoder._self_attention._W_q.6.Linea...   36.864k   36.864k
# 28__latent_encoder._self_attention._W_k.7.Linea...   36.864k   36.864k
# 29__latent_encoder._self_attention._W_v.7.Linea...   36.864k   36.864k
# 30__latent_encoder._self_attention._W_q.7.Linea...   36.864k   36.864k
# 31__latent_encoder._self_attention._W.Linear_li...  294.912k  294.912k
# 32__latent_encoder.Linear__penultimate_layer         37.056k   36.864k
# 33__latent_encoder.Linear__mean                      37.056k   36.864k
# 34__latent_encoder.Linear__log_var                   37.056k   36.864k
# 35__latent_encoder.Linear__input_layer                     -    3.456k
# 36__latent_encoder._encoder.0.Linear_linear                -   36.864k
# 37__latent_encoder._encoder.0.ReLU_act                     -         -
# 38__latent_encoder._encoder.0.Dropout2d_dropout            -         -
# 39__latent_encoder._encoder.1.Linear_linear                -   36.864k
# 40__latent_encoder._encoder.1.ReLU_act                     -         -
# 41__latent_encoder._encoder.1.Dropout2d_dropout            -         -
# 42__latent_encoder._self_attention._W_k.0.Linea...         -   36.864k
# 43__latent_encoder._self_attention._W_v.0.Linea...         -   36.864k
# 44__latent_encoder._self_attention._W_q.0.Linea...         -   36.864k
# 45__latent_encoder._self_attention._W_k.1.Linea...         -   36.864k
# 46__latent_encoder._self_attention._W_v.1.Linea...         -   36.864k
# 47__latent_encoder._self_attention._W_q.1.Linea...         -   36.864k
# 48__latent_encoder._self_attention._W_k.2.Linea...         -   36.864k
# 49__latent_encoder._self_attention._W_v.2.Linea...         -   36.864k
# 50__latent_encoder._self_attention._W_q.2.Linea...         -   36.864k
# 51__latent_encoder._self_attention._W_k.3.Linea...         -   36.864k
# 52__latent_encoder._self_attention._W_v.3.Linea...         -   36.864k
# 53__latent_encoder._self_attention._W_q.3.Linea...         -   36.864k
# 54__latent_encoder._self_attention._W_k.4.Linea...         -   36.864k
# 55__latent_encoder._self_attention._W_v.4.Linea...         -   36.864k
# 56__latent_encoder._self_attention._W_q.4.Linea...         -   36.864k
# 57__latent_encoder._self_attention._W_k.5.Linea...         -   36.864k
# 58__latent_encoder._self_attention._W_v.5.Linea...         -   36.864k
# 59__latent_encoder._self_attention._W_q.5.Linea...         -   36.864k
# 60__latent_encoder._self_attention._W_k.6.Linea...         -   36.864k
# 61__latent_encoder._self_attention._W_v.6.Linea...         -   36.864k
# 62__latent_encoder._self_attention._W_q.6.Linea...         -   36.864k
# 63__latent_encoder._self_attention._W_k.7.Linea...         -   36.864k
# 64__latent_encoder._self_attention._W_v.7.Linea...         -   36.864k
# 65__latent_encoder._self_attention._W_q.7.Linea...         -   36.864k
# 66__latent_encoder._self_attention._W.Linear_li...         -  294.912k
# 67__latent_encoder.Linear__penultimate_layer               -   36.864k
# 68__latent_encoder.Linear__mean                            -   36.864k
# 69__latent_encoder.Linear__log_var                         -   36.864k
# 70__decoder.Linear__target_transform                  3.456k    3.264k
# 71__decoder._decoder.0.Linear_linear                147.456k  147.456k
# 72__decoder._decoder.0.ReLU_act                            -         -
# 73__decoder._decoder.0.Dropout2d_dropout                   -         -
# 74__decoder._decoder.1.Linear_linear                147.456k  147.456k
# 75__decoder._decoder.1.ReLU_act                            -         -
# 76__decoder._decoder.1.Dropout2d_dropout                   -         -
# 77__decoder._decoder.2.Linear_linear                147.456k  147.456k
# 78__decoder._decoder.2.ReLU_act                            -         -
# 79__decoder._decoder.2.Dropout2d_dropout                   -         -
# 80__decoder.Linear__mean                               385.0     384.0
# 81__decoder.Linear__std                                385.0     384.0
# -------------------------------------------------------------------------------------------------------
#                          Totals
# Total params          1.814786M
# Trainable params      1.814786M
# Non-trainable params        0.0
# Mult-Adds             3.181248M
# =======================================================================================================

# %%
# Lets choose a challenging time to forecast
vis_i = 670 # 290 # 1600
plot_from_loader(loader_test, model, i=vis_i)
# Out:
# tensor(0.8344, device='cuda:0')

# %%
epochs = 10
grad_clip = 40
history = []
for epoch in tqdm(range(epochs), unit='epoch'):

    pbar = tqdm(loader_train, unit='batch')
    for i, data in enumerate(pbar):
        model.train()
        assert all(torch.isfinite(d).all() for d in data)
        data = [d.to(device) for d in data]
        context_x, context_y, target_x, target_y = data

        optim.zero_grad()
        y_pred, kl, loss, loss_mse, y_std = model(context_x, context_y, target_x, target_y)

        # These attentive NP models work great when you need uncertainty, but still seem a bit unstable. 
        # Sometimes they produce nans, especically if the data is not fully normalized. 
        assert torch.isfinite(y_pred.sum())
        if not torch.isfinite(loss):
            logger.error("loss is not finite")
            continue
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
        if not np.isfinite(grad_norm):
            logger.error("grad_norm is not finite")
            continue
        optim.step()

        if i%100==0:
            model.eval()
            test_loss = plot_from_loader(loader_test, model, i=vis_i, plot=False)
            pbar.set_description(f"{epoch}, loss: {loss.item():4.4g}, test: {test_loss.item():4.4g}")
            print(f"{epoch}, i={i}, loss: {loss.item():4.4g}, test: {test_loss.item():4.4g}, grad_norm: {grad_norm: 2.2g}, std: {y_std.mean().item(): 2.2g}")
            
            history.append(dict(
                n=epoch*len(loader_train) + i,
                epoch=epoch,
                i=i,
                loss=loss.item(),
                kl=kl.mean().item(),
                test_loss=test_loss.item(),
                y_std=y_std.mean().item(),
                grad_norm=grad_norm,
            ))
            scheduler.step(loss.item())
        
    test_loss = plot_from_loader(loader_train, model, i=vis_i, title=f'epoch={epoch}, train,')
    plt.show()
    model.eval()
    test_loss = plot_from_loader(loader_test, model, i=vis_i, title=f'epoch={epoch}, test,')
    plt.show()
    print(f"epoch: {epoch}, loss: {loss.item():4.4g}, loss_test:{test_loss.item():4.4g}, kl={kl.mean().item():2.2g}, grad_norm: {grad_norm: 2.2g}")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1093.0), HTML(value='')))
# 0, i=0, loss: 0.7975, test: 0.8082, grad_norm:  1.3, std:  0.68
# 0, i=100, loss: -0.2183, test: -0.3447, grad_norm:  10, std:  0.18
# 0, i=200, loss: -0.3002, test: -0.6174, grad_norm:  4.6, std:  0.16
# 0, i=300, loss: -0.5643, test: -0.6592, grad_norm:  6.1, std:  0.16
# 0, i=400, loss: -0.05472, test: -0.3722, grad_norm:  22, std:  0.22
# 0, i=500, loss: -0.5082, test: -0.6556, grad_norm:  13, std:  0.2
# 0, i=600, loss: -0.7577, test: -0.595, grad_norm:  14, std:  0.13
# 0, i=700, loss: -0.8033, test: -0.8108, grad_norm:  3.7, std:  0.11
# 0, i=800, loss: -0.9265, test: -0.863, grad_norm:  20, std:  0.11
# 0, i=900, loss: -0.8924, test: -0.5864, grad_norm:  17, std:  0.13
# 0, i=1000, loss: -0.8474, test: -0.8609, grad_norm:  9.4, std:  0.14
# epoch: 0, loss: -1.009, loss_test:-0.91, kl=4.4e-05, grad_norm:  8.2
# HBox(children=(FloatProgress(value=0.0, max=1093.0), HTML(value='')))
# 1, i=0, loss: -0.6776, test: -0.8742, grad_norm:  14, std:  0.16
# 1, i=100, loss: -0.9819, test: -0.8792, grad_norm:  20, std:  0.11
# 1, i=200, loss: -0.9597, test: -0.8394, grad_norm:  22, std:  0.13
# 1, i=300, loss: -0.9841, test: -0.78, grad_norm:  13, std:  0.11
# 1, i=400, loss: -1.055, test: -0.8842, grad_norm:  9.8, std:  0.11
# 1, i=500, loss: -0.9756, test: -0.9412, grad_norm:  73, std:  0.1
# 1, i=600, loss: -1.183, test: -0.7212, grad_norm:  37, std:  0.087
# 1, i=700, loss: -1.142, test: -0.6027, grad_norm:  22, std:  0.096
# 1, i=800, loss: -1.123, test: -0.1813, grad_norm:  21, std:  0.096
# 1, i=900, loss: -1.179, test: -0.5516, grad_norm:  45, std:  0.1
# 1, i=1000, loss: -0.9783, test: -0.3312, grad_norm:  9.1, std:  0.11
# epoch: 1, loss: -1.232, loss_test:-0.3241, kl=3.7e-05, grad_norm:  29
# HBox(children=(FloatProgress(value=0.0, max=1093.0), HTML(value='')))
# 2, i=0, loss: -1.36, test: -0.3286, grad_norm:  23, std:  0.085

# %%
for vis_i in [20, 50, 60, 70]:
    test_loss = plot_from_loader(loader_train, model, i=vis_i, title=f'epoch={epoch}, train,')
    plt.show()
    model.eval()
    test_loss = plot_from_loader(loader_test, model, i=vis_i, title=f'epoch={epoch}, test,')
    plt.show()

# %% [markdown]
# ## History

# %%
df_hist = pd.DataFrame(history)
df_hist['n'] = df_hist['n']/(df_hist['epoch']+1)
df_hist.head(3)

# %%
(df_hist[['loss', 'test_loss']]).plot(ylim=[-2,0])

# %%
df_hist[['y_std']].plot(ylim=[0,1e4], logy=True)
